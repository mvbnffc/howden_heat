# %%
import xarray as xr
import os
from pathlib import Path

# %%
# Set filepaths
root = Path.cwd().parent # find project root
heat_path = os.path.join(root, 'data', 'nex-gddp-cmip6.return_levels.zarr')

# %%
ds = xr.open_zarr(heat_path)

# %%
ds
# Out:
# <xarray.Dataset> Size: 87GB
# Dimensions:              (model: 35, scenario: 5, return_period: 6, epoch: 4,
#                           lat: 600, lon: 1440)
# Coordinates:
#   * model                (model) <U16 2kB 'ACCESS-CM2' ... 'UKESM1-0-LL'
#   * scenario             (scenario) <U10 200B 'historical' 'ssp126' ... 'ssp585'
#   * return_period        (return_period) int64 48B 20 50 100 200 500 1500
#   * epoch                (epoch) <U9 144B '1984-2014' ... '2066-2090'
#   * lat                  (lat) float64 5kB -59.88 -59.62 -59.38 ... 89.62 89.88
#   * lon                  (lon) float64 12kB 0.125 0.375 0.625 ... 359.6 359.9
# Data variables:
#     spei12_return_level  (model, scenario, return_period, epoch, lat, lon) float64 29GB ...
#     spei3_return_level   (model, scenario, return_period, epoch, lat, lon) float64 29GB ...
#     tasmax_return_level  (model, scenario, return_period, epoch, lat, lon) float64 29GB ...
# Attributes: (12/21)
# ...
